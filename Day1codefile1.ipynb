# %% [markdown]
# <a href="https://colab.research.google.com/github/Monikam98/INTERSOFTcodefiles/blob/main/Day1codefile1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is my title
#
# This is regular text
#
#
# ```
# # This is formatted as code
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10*np.pi, 1000)
y = np.sin(x)

# %%
plt.plot(x, y)
